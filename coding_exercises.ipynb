# %%
print("Hello World")

# %% [markdown]
# <h1>Hello, World!</h1>
# The following code is created as my first attempt at programming in this course, Its purpose is to help me understand how to write and run code in GitHub Codespaces

# %% [markdown]
# <h1>AI for Art and Humanities</h1>
# <p> This notebook is for learning basic programming concepts </p>
# <ul>
# <li>Build a website</li>
# <li>Build a AI program</li>
# <li>Build a game</li>
# </ul>
