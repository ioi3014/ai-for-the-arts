# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# <h1>Step 5 and 6 in Introducting GitHub Code Spaces</h1>
# This file is for learning basic programming concepts
# <p>learning basic programming concepts</p>
# <ul>
# <li>Be able to code a webside</li>
# <li>Be able to code a game</li>
# <li>Be able to code an AI</li>

# %% [markdown]
# <h1>Hello, World</h1>
# <p>The following code was my first attempt at programming in this course</p>
